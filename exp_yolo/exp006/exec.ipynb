# %%
# %cd /workspace/customized_yolov5/
# !sh /workspace/exp_yolo/exp006/run.sh
# Out:
# /workspace/customized_yolov5
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 191f708 torch 1.8.1+cu111 CUDA:0 (GeForce RTX 3090, 24259.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='models/hub/yolov5x6.yaml', data='/workspace/exp_yolo/config_000/config_0.yaml', device='', entity=None, epochs=35, evolve=False, exist_ok=True, global_rank=-1, hyp='/workspace/exp_yolo/exp006/hyp.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/workspace/output/yolo_exp006_cv0', noautoanchor=False, nosave=False, notest=False, project='siim_rsna_yolov5', quad=False, rect=False, resume=False, save_dir='/workspace/output/yolo_exp006_cv0', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='weights/yolov5x6.pt', workers=8, world_size=1)
# ...
